# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('mhealth_raw_data.csv')

# %% [markdown]
# * Column 1: acceleration from the chest sensor (X axis)
# * Column 2: acceleration from the chest sensor (Y axis)
# * Column 3: acceleration from the chest sensor (Z axis)
# * Column 4: electrocardiogram signal (lead 1)
# * Column 5: electrocardiogram signal (lead 2)
# * Column 6: acceleration from the left-ankle sensor (X axis)
# * Column 7: acceleration from the left-ankle sensor (Y axis)
# * Column 8: acceleration from the left-ankle sensor (Z axis)
# * Column 9: gyro from the left-ankle sensor (X axis)
# * Column 10: gyro from the left-ankle sensor (Y axis)
# * Column 11: gyro from the left-ankle sensor (Z axis)
# * Column 13: magnetometer from the left-ankle sensor (X axis)
# * Column 13: magnetometer from the left-ankle sensor (Y axis)
# * Column 14: magnetometer from the left-ankle sensor (Z axis)
# * Column 15: acceleration from the right-lower-arm sensor (X axis)
# * Column 16: acceleration from the right-lower-arm sensor (Y axis)
# * Column 17: acceleration from the right-lower-arm sensor (Z axis)
# * Column 18: gyro from the right-lower-arm sensor (X axis)
# * Column 19: gyro from the right-lower-arm sensor (Y axis)
# * Column 20: gyro from the right-lower-arm sensor (Z axis)
# * Column 21: magnetometer from the right-lower-arm sensor (X axis)
# * Column 22: magnetometer from the right-lower-arm sensor (Y axis)
# * Column 23: magnetometer from the right-lower-arm sensor (Z axis)
# * Column 24: Label (0 for the null class)

# %% [markdown]
# # EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1215745 entries, 0 to 1215744
# Data columns (total 14 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   alx       1215745 non-null  float64
#  1   aly       1215745 non-null  float64
#  2   alz       1215745 non-null  float64
#  3   glx       1215745 non-null  float64
#  4   gly       1215745 non-null  float64
#  5   glz       1215745 non-null  float64
#  6   arx       1215745 non-null  float64
#  7   ary       1215745 non-null  float64
#  8   arz       1215745 non-null  float64
#  9   grx       1215745 non-null  float64
#  10  gry       1215745 non-null  float64
#  11  grz       1215745 non-null  float64
#  12  Activity  1215745 non-null  int64
#  13  subject   1215745 non-null  object
# dtypes: float64(12), int64(1), object(1)
# memory usage: 129.9+ MB

# %%
data.describe()
# Out:
#                 alx           aly           alz           glx           gly  \
# count  1.215745e+06  1.215745e+06  1.215745e+06  1.215745e+06  1.215745e+06
# mean   1.494200e+00 -9.692878e+00 -9.548056e-01 -1.598951e-03 -6.166318e-01
# std    3.826485e+00  4.171303e+00  5.461803e+00  4.912172e-01  3.546406e-01
# min   -2.214600e+01 -1.961900e+01 -1.937300e+01 -2.146600e+00 -7.789900e+00
# 25%    1.413100e-01 -1.020100e+01 -2.649400e+00 -4.359900e-01 -8.180100e-01
# 50%    1.308900e+00 -9.670300e+00 -1.645600e-02 -1.484200e-02 -7.073200e-01
# 75%    2.575800e+00 -9.042200e+00  1.301300e+00  4.489800e-01 -5.403400e-01
# max    2.005400e+01  2.116100e+01  2.501500e+01  6.048400e+01  2.011300e+00
#
#                 glz           arx           ary           arz           grx  \
# count  1.215745e+06  1.215745e+06  1.215745e+06  1.215745e+06  1.215745e+06
# mean  -1.587811e-01 -3.713413e+00 -5.805526e+00  2.393880e+00 -2.761061e-01
# std    5.467979e-01  4.763586e+00  5.757639e+00  3.876503e+00  5.276888e-01
# min   -2.626700e+00 -2.236100e+01 -1.897200e+01 -1.823900e+01 -8.339200e+00
# 25%   -5.933200e-01 -6.076000e+00 -9.404200e+00  1.296500e-01 -7.058800e-01
# 50%   -1.905700e-01 -2.977600e+00 -7.461500e+00  1.928100e+00 -3.549000e-01
# 75%    3.222000e-01 -1.193700e+00 -2.533900e+00  4.914700e+00  9.607800e-02
# max    2.770100e+00  1.986400e+01  2.219100e+01  2.574100e+01  3.319600e+00
#
#                 gry           grz      Activity
# count  1.215745e+06  1.215745e+06  1.215745e+06
# mean  -4.664340e-01  2.666335e-01  1.741465e+00
# std    5.555510e-01  5.643804e-01  3.283679e+00
# min   -3.570800e+00 -2.689700e+00  0.000000e+00
# 25%   -8.973300e-01 -2.370700e-01  0.000000e+00
# 50%   -6.345000e-01  3.017200e-01  0.000000e+00
# 75%   -1.067800e-01  7.780200e-01  2.000000e+00
# max    1.556500e+00  2.750000e+00  1.200000e+01

# %%
data.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_45463_row0_col0,#T_45463_row1_col1,#T_45463_row2_col2,#T_45463_row3_col3,#T_45463_row4_col4,#T_45463_row5_col5,#T_45463_row6_col6,#T_45463_row7_col7,#T_45463_row8_col8,#T_45463_row9_col9,#T_45463_row10_col10,#T_45463_row11_col11,#T_45463_row12_col12{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_45463_row0_col1,#T_45463_row6_col0,#T_45463_row6_col3,#T_45463_row6_col7{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_45463_row0_col2,#T_45463_row3_col1,#T_45463_row9_col1{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_45463_row0_col3,#T_45463_row8_col0{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_45463_row0_col4,#T_45463_row3_col7{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_45463_row0_col5,#T_45463_row6_col11,#T_45463_row9_col11,#T_45463_row11_col1{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_45463_row0_col6,#T_45463_row3_col2,#T_45463_row4_col5{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_45463_row0_col7{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_45463_row0_col8{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_45463_row0_col9{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_45463_row0_col10,#T_45463_row7_col2,#T_45463_row8_col7{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_45463_row0_col11,#T_45463_row5_col12{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_45463_row0_col12,#T_45463_row1_col8{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_45463_row1_col0{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_45463_row1_col2,#T_45463_row7_col8,#T_45463_row12_col6{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_45463_row1_col3{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_45463_row1_col4{
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }#T_45463_row1_col5,#T_45463_row3_col12{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_45463_row1_col6,#T_45463_row5_col6{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_45463_row1_col7{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_45463_row1_col9,#T_45463_row12_col9{
#             background-color:  #94b6ff;
#             color:  #000000;
#         }#T_45463_row1_col10,#T_45463_row4_col1,#T_45463_row5_col11,#T_45463_row8_col9{
#             background-color:  #afcafc;
#             color:  #000000;
#         }#T_45463_row1_col11,#T_45463_row4_col12{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_45463_row1_col12,#T_45463_row2_col6,#T_45463_row5_col4,#T_45463_row6_col12,#T_45463_row11_col0{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_45463_row2_col0,#T_45463_row2_col11,#T_45463_row2_col12,#T_45463_row6_col2,#T_45463_row6_col4,#T_45463_row7_col3,#T_45463_row9_col5,#T_45463_row9_col7,#T_45463_row9_col10,#T_45463_row10_col6,#T_45463_row10_col9,#T_45463_row12_col1,#T_45463_row12_col8{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_45463_row2_col1,#T_45463_row12_col5{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_45463_row2_col3,#T_45463_row5_col0,#T_45463_row12_col2{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_45463_row2_col4,#T_45463_row5_col2{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_45463_row2_col5{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_45463_row2_col7{
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }#T_45463_row2_col8,#T_45463_row3_col0,#T_45463_row7_col0,#T_45463_row12_col11{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_45463_row2_col9,#T_45463_row10_col4,#T_45463_row11_col6{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_45463_row2_col10{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_45463_row3_col4,#T_45463_row7_col4{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_45463_row3_col5{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_45463_row3_col6{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_45463_row3_col8{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_45463_row3_col9{
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }#T_45463_row3_col10{
#             background-color:  #8db0fe;
#             color:  #000000;
#         }#T_45463_row3_col11,#T_45463_row11_col3{
#             background-color:  #f1cdba;
#             color:  #000000;
#         }#T_45463_row4_col0,#T_45463_row9_col2{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_45463_row4_col2,#T_45463_row8_col6,#T_45463_row10_col11{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_45463_row4_col3,#T_45463_row10_col8{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_45463_row4_col6,#T_45463_row5_col3,#T_45463_row5_col9,#T_45463_row12_col0{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_45463_row4_col7{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_45463_row4_col8,#T_45463_row12_col3{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_45463_row4_col9{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_45463_row4_col10{
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }#T_45463_row4_col11,#T_45463_row6_col8,#T_45463_row9_col12,#T_45463_row10_col0{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_45463_row5_col1{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_45463_row5_col7,#T_45463_row6_col5,#T_45463_row8_col2,#T_45463_row9_col8,#T_45463_row11_col4,#T_45463_row11_col12{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_45463_row5_col8,#T_45463_row8_col1{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_45463_row5_col10{
#             background-color:  #ead4c8;
#             color:  #000000;
#         }#T_45463_row6_col1{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_45463_row6_col9{
#             background-color:  #e2dad5;
#             color:  #000000;
#         }#T_45463_row6_col10,#T_45463_row8_col3{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_45463_row7_col1,#T_45463_row11_col2,#T_45463_row12_col4{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_45463_row7_col5{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_45463_row7_col6{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_45463_row7_col9,#T_45463_row7_col11{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_45463_row7_col10{
#             background-color:  #f7b194;
#             color:  #000000;
#         }#T_45463_row7_col12{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_45463_row8_col4,#T_45463_row10_col1{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_45463_row8_col5,#T_45463_row10_col2,#T_45463_row12_col7{
#             background-color:  #7396f5;

# %%
axes = data.Activity.value_counts().plot.barh(figsize=(20, 10))

for i, v in enumerate(data.Activity.value_counts()):
    axes.text(v, i-0.1, str(v), color='blue', fontweight='bold')

# %% [markdown]
# Очень серьезный дизбаланс классов. Значит,позже используем class_weight и соответствующую метрику (F-score, ROC-AUC или что-то подобное)

# %%
fig, axes = plt.subplots(figsize=(20, 20), nrows=7, ncols=2)

activity_grouped_data = data.groupby('Activity')

for i, activity in enumerate(data.Activity.unique()):
    activity_data = activity_grouped_data.get_group(activity)
    
    activity_data.drop(columns=['subject', 'Activity']).mean().plot.bar(ax=axes[i//2, i%2])
    axes[i//2, i%2].set_title(activity)

# %% [markdown]
# Из графиков выше видно, что активности неплохо разделимы между собой по показаниям сенсоров. Попробуем использовать понижение размерности для лучшей иллюстрации разделимости

# %%
from sklearn.decomposition import PCA

data_decomposed = PCA().fit_transform(data.drop(columns=['subject', 'Activity']))

# %%
data_decomposed
# Out:
# array([[ 2.90246455e+00,  3.24849972e-01, -4.68361133e+00, ...,
#          3.38578877e-01,  5.45219416e-04,  1.42551863e-02],
#        [ 3.12738446e+00,  1.88895403e-01, -4.61911116e+00, ...,
#          3.51710965e-01, -5.65816429e-03, -6.61061499e-03],
#        [ 3.14912240e+00,  1.57118221e-01, -4.45053607e+00, ...,
#          3.50741833e-01, -7.41387688e-03,  3.96391476e-03],
#        ...,
#        [-2.14416545e+00,  2.80899605e+00, -1.33996410e+00, ...,
#          2.11584249e-01,  1.84261983e-01, -3.16545018e-02],
#        [-2.12834912e+00,  2.97308502e+00, -8.88319700e-01, ...,
#          2.09285721e-01,  1.91546379e-01, -1.99554860e-02],
#        [-1.94294615e+00,  2.71330219e+00, -1.19056103e+00, ...,
#          2.37069112e-01,  1.69747976e-01, -2.14490204e-02]])

# %%
plt.figure(figsize=(20, 15))

plt.scatter(data_decomposed[:, 0], data_decomposed[:, 1], c = data.Activity, s=5)

# %% [markdown]
# PCA не смог продемонстрировать линейную разделимость. Возможно, в будущем используем более мощный инструмент

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# Данные в хорошем состоянии, поэтому пока препроцессинг делать не будем. Колонку "subject" уберем т.к. в качестве категориального признака ее учесть нельзя (в будущем появятся новые subject'ы) и ее отсутствие поможет лучше подстроиться под движения людей в целом, а не subject'ов в частности.

# %%
from sklearn.model_selection import train_test_split

X = data.drop(columns=['Activity', 'subject'])
y = data.Activity

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, shuffle=True, stratify=y)

assert X_train.shape[1] == X_val.shape[1]
assert X_train.shape[0] == y_train.shape[0]
assert X_val.shape[0] == y_val.shape[0]

print(f'X train shape - {X_train.shape}, y train shape - {y_train.shape}')
print(f'X val shape - {X_val.shape}, y val shape - {y_val.shape}')
# Out:
# X train shape - (972596, 12), y train shape - (972596,)
# X val shape - (243149, 12), y val shape - (243149,)

# %% [markdown]
# # CatBoostClassifier

# %%
from catboost import CatBoostClassifier, metrics
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight(classes=np.unique(y), y=y, class_weight='balanced')
class_weights = dict(zip(np.unique(y), class_weights))

clf = CatBoostClassifier(class_weights=class_weights, iterations=2000).fit(X_train, y_train, eval_set=(X_val, y_val),  early_stopping_rounds=50, verbose=100)
# Out:
# Learning rate set to 0.095081
# 0:	learn: 2.2351013	test: 2.2345144	best: 2.2345144 (0)	total: 615ms	remaining: 20m 30s
# 100:	learn: 0.3742287	test: 0.3765801	best: 0.3765801 (100)	total: 55.3s	remaining: 17m 20s
# 200:	learn: 0.2393153	test: 0.2438081	best: 0.2438081 (200)	total: 1m 50s	remaining: 16m 24s
# 300:	learn: 0.1884837	test: 0.1945849	best: 0.1945849 (300)	total: 2m 43s	remaining: 15m 24s
# 400:	learn: 0.1620040	test: 0.1692704	best: 0.1692704 (400)	total: 3m 37s	remaining: 14m 27s
# 500:	learn: 0.1438718	test: 0.1521733	best: 0.1521733 (500)	total: 4m 31s	remaining: 13m 31s
# 600:	learn: 0.1323572	test: 0.1414530	best: 0.1414530 (600)	total: 5m 24s	remaining: 12m 36s
# 700:	learn: 0.1230343	test: 0.1328376	best: 0.1328376 (700)	total: 6m 18s	remaining: 11m 41s
# 800:	learn: 0.1157357	test: 0.1261722	best: 0.1261722 (800)	total: 7m 12s	remaining: 10m 47s
# 900:	learn: 0.1098603	test: 0.1208964	best: 0.1208964 (900)	total: 8m 5s	remaining: 9m 52s
# 1000:	learn: 0.1052076	test: 0.1166340	best: 0.1166340 (1000)	total: 8m 59s	remaining: 8m 58s
# 1100:	learn: 0.1009108	test: 0.1127353	best: 0.1127353 (1100)	total: 9m 52s	remaining: 8m 4s
# 1200:	learn: 0.0972540	test: 0.1095167	best: 0.1095167 (1200)	total: 10m 46s	remaining: 7m 9s
# 1300:	learn: 0.0940876	test: 0.1067170	best: 0.1067170 (1300)	total: 11m 39s	remaining: 6m 15s
# 1400:	learn: 0.0910498	test: 0.1040265	best: 0.1040265 (1400)	total: 12m 33s	remaining: 5m 22s
# 1500:	learn: 0.0882724	test: 0.1015402	best: 0.1015402 (1500)	total: 13m 26s	remaining: 4m 28s
# 1600:	learn: 0.0859566	test: 0.0995376	best: 0.0995376 (1600)	total: 14m 20s	remaining: 3m 34s
# 1700:	learn: 0.0837056	test: 0.0976249	best: 0.0976249 (1700)	total: 15m 14s	remaining: 2m 40s
# 1800:	learn: 0.0817542	test: 0.0959288	best: 0.0959288 (1800)	total: 16m 9s	remaining: 1m 47s
# 1900:	learn: 0.0798697	test: 0.0943307	best: 0.0943307 (1900)	total: 17m 7s	remaining: 53.5s
# 1999:	learn: 0.0781648	test: 0.0928875	best: 0.0928875 (1999)	total: 18m 5s	remaining: 0us
#
# bestTest = 0.09288747901
# bestIteration = 1999

# %%
from sklearn.metrics import f1_score

f_score = f1_score(y_val, clf.predict(X_val)[:, 0], average="weighted")

print(f'Validation accuracy - {clf.score(X_val, y_val)}')
print(f'Validation f-score - {f_score}')
# Out:
# Validation accuracy - 0.8546158939580257
# Validation f-score - 0.8627795363229632

# %% [markdown]
# # Not CatBoost

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_clf = KNeighborsClassifier().fit(X_train, y_train)

# %%
from sklearn.metrics import f1_score

f_score = f1_score(y_val, knn_clf.predict(X_val), average="weighted")

print(f'Validation accuracy - {knn_clf.score(X_val, y_val)}')
print(f'Validation f-score - {f_score}')
# Out:
# Validation accuracy - 0.8572480248736372
# Validation f-score - 0.8563805921595123

# %%
from sklearn.linear_model import SGDClassifier

sgd_clf = SGDClassifier().fit(X_train, y_train)

# %%
from sklearn.metrics import f1_score

f_score = f1_score(y_val, sgd_clf.predict(X_val), average="weighted")

print(f'Validation accuracy - {sgd_clf.score(X_val, y_val)}')
print(f'Validation f-score - {f_score}')
# Out:
# Validation accuracy - 0.723284899382683
# Validation f-score - 0.6178535692518455
